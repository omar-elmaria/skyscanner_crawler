# %%
import requests
import json
import pandas as pd
import os
import time
from openpyxl import load_workbook
import warnings
warnings.filterwarnings(action="ignore")
from dotenv import load_dotenv
# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Define some global inputs

# %%
airport_data_excel_file = "airport_data.xlsx"
failed_airports_excel_file = "failed_airports.xlsx"

# %% [markdown]
# ### Load the flight routes from the Excel file

# %%
df_routes = pd.read_excel("flight_routes.xlsx")

# Display the data frame
df_routes.columns = df_routes.columns.str.lower().str.replace(" ", "_")
df_routes
# Out:
#      departure_city arrival_city route_competition_status
# 0           Aalborg       Kaunas          Monopoly always
# 1           Aalborg       Kaunas          Monopoly always
# 2           Aalborg  London (GB)      Monopoly not always
# 3           Aalborg    Stockholm          Monopoly always
# 4            Aarhus    Faro (PT)          Monopoly always
# ...             ...          ...                      ...
# 5116          Zadar   Paris (FR)           1 comp No Wizz
# 5117          Zadar       Vienna           1 comp No Wizz
# 5118         Zagreb  Dublin (IE)           1 comp No Wizz
# 5119         Zagreb  Duesseldorf           1 comp No Wizz
# 5120       Zaragoza   Paris (FR)           1 comp No Wizz
#
# [5121 rows x 3 columns]

# %%
# Create a list of all airports from df_routes
airport_list = pd.concat([df_routes["departure_city"], df_routes["arrival_city"]], axis=0).drop_duplicates().reset_index(drop=True).sort_values().tolist()

# Clean the list so only valid airports are shown
failed_airports_mapping_dict = {
    "Duesseldorf": "Düsseldorf",
    "Basel/Mulhouse": "Basel",
    "Cologne/Bonn": "Cologne",
    "Karlsruhe/Baden-Baden": "Karlsruhe",
    "Klaipeda/Palanga": "Palanga",
    "Leipzig/Halle": "Leipzig",
    "Lourdes/Tarbes": "Tarbes",
    "Maastricht/Aachen (NL)": "Maastricht",
    "Muenster/Osnabrueck (DE) 00": "Münster",
    "Paderborn/Lippstadt": "Paderborn Lippstadt",
    "Preveza/Lefkada": "Preveza",

}
airport_list = [failed_airports_mapping_dict.get(airport) if airport in list(failed_airports_mapping_dict.keys()) else airport for airport in airport_list]

# %% [markdown]
# ### Define a function to extract the airport based on the city name

# %%
def extract_airport(city_name):
    url = "https://skyscanner50.p.rapidapi.com/api/v1/searchAirport"

    querystring = {"query": city_name}

    headers = {
        "X-RapidAPI-Key": os.getenv("API_KEY"),
        "X-RapidAPI-Host": "skyscanner50.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

# %% [markdown]
# ### Call the airport data endpoint to retrieve information about the airports found in the cities

# %%
list_airport_data = []
list_failed_airports = []
for idx, i in enumerate(airport_list):
    # Print a status message
    print(f"Extracting the airport data of airport {i}, which is airport number {idx + 1} out of {len(airport_list)}")
    
    # Get the airport data and create a data frame out of it
    try:
        output_extract_airport = pd.json_normalize(extract_airport(i)["data"][0])
        output_extract_airport["search_term"] = i

        # Append the result to airport_list
        list_airport_data.append(output_extract_airport)

        # Write the result to Excel
        with pd.ExcelWriter(airport_data_excel_file, mode='a', engine='openpyxl', if_sheet_exists="overlay") as writer:
            last_row = pd.read_excel(airport_data_excel_file).shape[0]
            if idx == 0:
                output_extract_airport.to_excel(writer, sheet_name='Sheet1', index=False, header=True, encoding="utf-8", startrow=last_row)
            else:
                output_extract_airport.to_excel(writer, sheet_name='Sheet1', index=False, header=False, encoding="utf-8", startrow=last_row + 1)
     # This KeyError can occur because the airport cannot be found in the data object of the API
     # The IndexError occurs because the airport cannot be found in the 0th index of the API response
    except (KeyError, IndexError): 
        list_failed_airports.append(i)
        
        # Write the result to Excel
        with pd.ExcelWriter(failed_airports_excel_file, mode='a', engine='openpyxl', if_sheet_exists="overlay") as writer:
            last_row = pd.read_excel(failed_airports_excel_file).shape[0]
            pd.DataFrame({"failed_airport": [i]}).to_excel(writer, sheet_name='Sheet1', index=False, header=False, encoding="utf-8", startrow=last_row + 1)

    # Introduce a sleep of 0.5 second between each call and the next
    time.sleep(0.5)

# Change list_airport_data to a dataframe
df_airport_data = pd.concat(list_airport_data).reset_index(drop=True)
# Out:
# Extracting the airport data of airport Aalborg, which is airport number 1 out of 229
# Extracting the airport data of airport Aarhus, which is airport number 2 out of 229
# Extracting the airport data of airport Aberdeen (GB), which is airport number 3 out of 229
# Extracting the airport data of airport Agadir, which is airport number 4 out of 229
# Extracting the airport data of airport Alghero, which is airport number 5 out of 229
# Extracting the airport data of airport Alicante, which is airport number 6 out of 229
# Extracting the airport data of airport Almeria, which is airport number 7 out of 229
# Extracting the airport data of airport Amman, which is airport number 8 out of 229
# Extracting the airport data of airport Amsterdam, which is airport number 9 out of 229
# Extracting the airport data of airport Ancona, which is airport number 10 out of 229
# Extracting the airport data of airport Aqaba, which is airport number 11 out of 229
# Extracting the airport data of airport Asturias, which is airport number 12 out of 229
# Extracting the airport data of airport Athens (GR), which is airport number 13 out of 229
# Extracting the airport data of airport Banja Luka, which is airport number 14 out of 229
# Extracting the airport data of airport Barcelona (ES), which is airport number 15 out of 229
# Extracting the airport data of airport Bari, which is airport number 16 out of 229
# Extracting the airport data of airport Basel, which is airport number 17 out of 229
# Extracting the airport data of airport Belfast, which is airport number 18 out of 229
# Extracting the airport data of airport Bergerac, which is airport number 19 out of 229
# Extracting the airport data of airport Berlin (DE), which is airport number 20 out of 229
# Extracting the airport data of airport Berlin (DE) 00, which is airport number 21 out of 229
# Extracting the airport data of airport Beziers, which is airport number 22 out of 229
# Extracting the airport data of airport Biarritz, which is airport number 23 out of 229
# Extracting the airport data of airport Billund, which is airport number 24 out of 229
# Extracting the airport data of airport Birmingham (GB), which is airport number 25 out of 229
# Extracting the airport data of airport Bodrum, which is airport number 26 out of 229
# Extracting the airport data of airport Bodrum (TR), which is airport number 27 out of 229
# Extracting the airport data of airport Bologna, which is airport number 28 out of 229
# Extracting the airport data of airport Bordeaux, which is airport number 29 out of 229
# Extracting the airport data of airport Bournemouth, which is airport number 30 out of 229
# Extracting the airport data of airport Bratislava, which is airport number 31 out of 229
# Extracting the airport data of airport Bremen (DE) 00, which is airport number 32 out of 229
# Extracting the airport data of airport Brindisi, which is airport number 33 out of 229
# Extracting the airport data of airport Bristol (GB), which is airport number 34 out of 229
# Extracting the airport data of airport Brive-La-Gaillarde, which is airport number 35 out of 229
# Extracting the airport data of airport Brno, which is airport number 36 out of 229
# Extracting the airport data of airport Brussels, which is airport number 37 out of 229
# Extracting the airport data of airport Bucharest, which is airport number 38 out of 229
# Extracting the airport data of airport Budapest, which is airport number 39 out of 229
# Extracting the airport data of airport Burgas, which is airport number 40 out of 229
# Extracting the airport data of airport Bydgoszcz, which is airport number 41 out of 229
# Extracting the airport data of airport Cagliari, which is airport number 42 out of 229
# Extracting the airport data of airport Carcassonne, which is airport number 43 out of 229
# Extracting the airport data of airport Cardiff (GB), which is airport number 44 out of 229
# Extracting the airport data of airport Castellon de la Plana, which is airport number 45 out of 229
# Extracting the airport data of airport Catania, which is airport number 46 out of 229
# Extracting the airport data of airport Chania, which is airport number 47 out of 229
# Extracting the airport data of airport Clermont-Ferrand, which is airport number 48 out of 229
# Extracting the airport data of airport Cluj-Napoca, which is airport number 49 out of 229
# Extracting the airport data of airport Cologne, which is airport number 50 out of 229
# Extracting the airport data of airport Comiso, which is airport number 51 out of 229
# Extracting the airport data of airport Copenhagen, which is airport number 52 out of 229
# Extracting the airport data of airport Cork, which is airport number 53 out of 229
# Extracting the airport data of airport Crotone, which is airport number 54 out of 229
# Extracting the airport data of airport Cuneo, which is airport number 55 out of 229
# Extracting the airport data of airport Dalaman, which is airport number 56 out of 229
# Extracting the airport data of airport Derry, which is airport number 57 out of 229
# Extracting the airport data of airport Dole, which is airport number 58 out of 229
# Extracting the airport data of airport Dortmund, which is airport number 59 out of 229
# Extracting the airport data of airport Dresden, which is airport number 60 out of 229
# Extracting the airport data of airport Dublin (IE), which is airport number 61 out of 229
# Extracting the airport data of airport Dubrovnik, which is airport number 62 out of 229
# Extracting the airport data of airport Düsseldorf, which is airport number 63 out of 229
# Extracting the airport data of airport Edinburgh, which is airport number 64 out of 229
# Extracting the airport data of airport Eilat (IL), which is airport number 65 out of 229
# Extracting the airport data of airport Eindhoven, which is airport number 66 out of 229
# Extracting the airport data of airport Essaouira, which is airport number 67 out of 229
# Extracting the airport data of airport Exeter (GB), which is airport number 68 out of 229
# Extracting the airport data of airport Faro (PT), which is airport number 69 out of 229
# Extracting the airport data of airport Fes, which is airport number 70 out of 229
# Extracting the airport data of airport Figari, which is airport number 71 out of 229
# Extracting the airport data of airport Forli, which is airport number 72 out of 229
# Extracting the airport data of airport Frankfurt, which is airport number 73 out of 229
# Extracting the airport data of airport Fuerteventura, which is airport number 74 out of 229
# Extracting the airport data of airport Funchal, which is airport number 75 out of 229
# Extracting the airport data of airport Gdansk, which is airport number 76 out of 229
# Extracting the airport data of airport Genoa, which is airport number 77 out of 229
# Extracting the airport data of airport Girona, which is airport number 78 out of 229
# Extracting the airport data of airport Glasgow (GB), which is airport number 79 out of 229
# Extracting the airport data of airport Goteborg, which is airport number 80 out of 229
# Extracting the airport data of airport Gran Canaria, which is airport number 81 out of 229
# Extracting the airport data of airport Hamburg, which is airport number 82 out of 229
# Extracting the airport data of airport Haugesund, which is airport number 83 out of 229
# Extracting the airport data of airport Helsinki, which is airport number 84 out of 229
# Extracting the airport data of airport Iasi, which is airport number 85 out of 229
# Extracting the airport data of airport Ibiza, which is airport number 86 out of 229
# Extracting the airport data of airport Irakleion, which is airport number 87 out of 229
# Extracting the airport data of airport Jerez, which is airport number 88 out of 229
# Extracting the airport data of airport Kalamata, which is airport number 89 out of 229
# Extracting the airport data of airport Karlsruhe, which is airport number 90 out of 229
# Extracting the airport data of airport Katowice, which is airport number 91 out of 229
# Extracting the airport data of airport Kaunas, which is airport number 92 out of 229
# Extracting the airport data of airport Kefallinia, which is airport number 93 out of 229
# Extracting the airport data of airport Kerkyra, which is airport number 94 out of 229
# Extracting the airport data of airport Kerry, which is airport number 95 out of 229
# Extracting the airport data of airport Klagenfurt, which is airport number 96 out of 229
# Extracting the airport data of airport Palanga, which is airport number 97 out of 229
# Extracting the airport data of airport Knock, which is airport number 98 out of 229
# Extracting the airport data of airport Kos, which is airport number 99 out of 229
# Extracting the airport data of airport Kosice, which is airport number 100 out of 229
# Extracting the airport data of airport Krakow, which is airport number 101 out of 229
# Extracting the airport data of airport La Rochelle, which is airport number 102 out of 229
# Extracting the airport data of airport Lamezia Terme, which is airport number 103 out of 229
# Extracting the airport data of airport Lanzarote, which is airport number 104 out of 229
# Extracting the airport data of airport Lappeenranta, which is airport number 105 out of 229
# Extracting the airport data of airport Larnaca, which is airport number 106 out of 229
# Extracting the airport data of airport Leeds Bradford, which is airport number 107 out of 229
# Extracting the airport data of airport Leipzig, which is airport number 108 out of 229
# Extracting the airport data of airport Lille (FR), which is airport number 109 out of 229
# Extracting the airport data of airport Limoges, which is airport number 110 out of 229
# Extracting the airport data of airport Lisbon, which is airport number 111 out of 229
# Extracting the airport data of airport Liverpool, which is airport number 112 out of 229
# Extracting the airport data of airport Lodz, which is airport number 113 out of 229
# Extracting the airport data of airport London (GB), which is airport number 114 out of 229
# Extracting the airport data of airport Tarbes, which is airport number 115 out of 229
# Extracting the airport data of airport Lublin, which is airport number 116 out of 229
# Extracting the airport data of airport Lulea, which is airport number 117 out of 229
# Extracting the airport data of airport Luxembourg, which is airport number 118 out of 229
# Extracting the airport data of airport Lyon, which is airport number 119 out of 229
# Extracting the airport data of airport Maastricht, which is airport number 120 out of 229
# Extracting the airport data of airport Madrid, which is airport number 121 out of 229
# Extracting the airport data of airport Malaga, which is airport number 122 out of 229
# Extracting the airport data of airport Malmo, which is airport number 123 out of 229
# Extracting the airport data of airport Malta (MT), which is airport number 124 out of 229
# Extracting the airport data of airport Manchester (GB), which is airport number 125 out of 229
# Extracting the airport data of airport Marrakech, which is airport number 126 out of 229
# Extracting the airport data of airport Marseille, which is airport number 127 out of 229
# Extracting the airport data of airport Memmingen, which is airport number 128 out of 229
# Extracting the airport data of airport Menorca, which is airport number 129 out of 229
# Extracting the airport data of airport Milan, which is airport number 130 out of 229
# Extracting the airport data of airport Münster, which is airport number 131 out of 229
# Extracting the airport data of airport Murcia (ES), which is airport number 132 out of 229
# Extracting the airport data of airport Mykonos, which is airport number 133 out of 229
# Extracting the airport data of airport Nador, which is airport number 134 out of 229
# Extracting the airport data of airport Nantes, which is airport number 135 out of 229
# Extracting the airport data of airport Naples (IT), which is airport number 136 out of 229
# Extracting the airport data of airport Newcastle (GB), which is airport number 137 out of 229
# Extracting the airport data of airport Newquay, which is airport number 138 out of 229
# Extracting the airport data of airport Nice, which is airport number 139 out of 229
# Extracting the airport data of airport Nimes, which is airport number 140 out of 229
# Extracting the airport data of airport Nis, which is airport number 141 out of 229
# Extracting the airport data of airport Nottingham, which is airport number 142 out of 229
# Extracting the airport data of airport Nowy Dwor Mazowiecki, which is airport number 143 out of 229
# Extracting the airport data of airport Nuremberg (DE), which is airport number 144 out of 229
# Extracting the airport data of airport Oradea, which is airport number 145 out of 229
# Extracting the airport data of airport Orebro, which is airport number 146 out of 229
# Extracting the airport data of airport Oslo, which is airport number 147 out of 229
# Extracting the airport data of airport Ostrava, which is airport number 148 out of 229
# Extracting the airport data of airport Ouarzazate, which is airport number 149 out of 229
# Extracting the airport data of airport Oujda, which is airport number 150 out of 229
# Extracting the airport data of airport Paderborn Lippstadt, which is airport number 151 out of 229
# Extracting the airport data of airport Palermo, which is airport number 152 out of 229
# Extracting the airport data of airport Palma de Mallorca, which is airport number 153 out of 229
# Extracting the airport data of airport Paphos, which is airport number 154 out of 229
# Extracting the airport data of airport Pardubice, which is airport number 155 out of 229
# Extracting the airport data of airport Paris (FR), which is airport number 156 out of 229
# Extracting the airport data of airport Perpignan, which is airport number 157 out of 229
# Extracting the airport data of airport Perugia, which is airport number 158 out of 229
# Extracting the airport data of airport Pescara, which is airport number 159 out of 229
# Extracting the airport data of airport Pisa, which is airport number 160 out of 229
# Extracting the airport data of airport Plovdiv, which is airport number 161 out of 229
# Extracting the airport data of airport Podgorica, which is airport number 162 out of 229
# Extracting the airport data of airport Poitiers, which is airport number 163 out of 229
# Extracting the airport data of airport Ponta Delgada, which is airport number 164 out of 229
# Extracting the airport data of airport Porto, which is airport number 165 out of 229
# Extracting the airport data of airport Poznan, which is airport number 166 out of 229
# Extracting the airport data of airport Prague, which is airport number 167 out of 229
# Extracting the airport data of airport Preveza, which is airport number 168 out of 229
# Extracting the airport data of airport Pula, which is airport number 169 out of 229
# Extracting the airport data of airport Rabat, which is airport number 170 out of 229
# Extracting the airport data of airport Reus, which is airport number 171 out of 229
# Extracting the airport data of airport Rhodes, which is airport number 172 out of 229
# Extracting the airport data of airport Riga, which is airport number 173 out of 229
# Extracting the airport data of airport Rijeka, which is airport number 174 out of 229
# Extracting the airport data of airport Rimini, which is airport number 175 out of 229
# Extracting the airport data of airport Rodez, which is airport number 176 out of 229
# Extracting the airport data of airport Rome (IT), which is airport number 177 out of 229
# Extracting the airport data of airport Rovaniemi, which is airport number 178 out of 229
# Extracting the airport data of airport Rzeszow, which is airport number 179 out of 229
# Extracting the airport data of airport Salzburg, which is airport number 180 out of 229
# Extracting the airport data of airport Santa Cruz de la Palma, which is airport number 181 out of 229
# Extracting the airport data of airport Santander, which is airport number 182 out of 229
# Extracting the airport data of airport Santiago de Compostela, which is airport number 183 out of 229
# Extracting the airport data of airport Sevilla, which is airport number 184 out of 229
# Extracting the airport data of airport Shannon, which is airport number 185 out of 229
# Extracting the airport data of airport Sibiu, which is airport number 186 out of 229
# Extracting the airport data of airport Skelleftea, which is airport number 187 out of 229
# Extracting the airport data of airport Skiathos, which is airport number 188 out of 229
# Extracting the airport data of airport Sofia, which is airport number 189 out of 229
# Extracting the airport data of airport Split, which is airport number 190 out of 229
# Extracting the airport data of airport Stockholm, which is airport number 191 out of 229
# Extracting the airport data of airport Strasbourg, which is airport number 192 out of 229
# Extracting the airport data of airport Suceava, which is airport number 193 out of 229
# Extracting the airport data of airport Szczecin, which is airport number 194 out of 229
# Extracting the airport data of airport Szczytno, which is airport number 195 out of 229
# Extracting the airport data of airport Tallinn, which is airport number 196 out of 229
# Extracting the airport data of airport Tampere, which is airport number 197 out of 229
# Extracting the airport data of airport Tangier, which is airport number 198 out of 229
# Extracting the airport data of airport Teesside, which is airport number 199 out of 229
# Extracting the airport data of airport Tel Aviv-yafo, which is airport number 200 out of 229
# Extracting the airport data of airport Tenerife, which is airport number 201 out of 229
# Extracting the airport data of airport Terceira, which is airport number 202 out of 229
# Extracting the airport data of airport Tetouan, which is airport number 203 out of 229
# Extracting the airport data of airport Thessaloniki, which is airport number 204 out of 229
# Extracting the airport data of airport Thira, which is airport number 205 out of 229
# Extracting the airport data of airport Timisoara, which is airport number 206 out of 229
# Extracting the airport data of airport Toulouse, which is airport number 207 out of 229
# Extracting the airport data of airport Tours, which is airport number 208 out of 229
# Extracting the airport data of airport Trapani, which is airport number 209 out of 229
# Extracting the airport data of airport Trieste, which is airport number 210 out of 229
# Extracting the airport data of airport Turin, which is airport number 211 out of 229
# Extracting the airport data of airport Tuzla, which is airport number 212 out of 229
# Extracting the airport data of airport Valencia (ES), which is airport number 213 out of 229
# Extracting the airport data of airport Valladolid, which is airport number 214 out of 229
# Extracting the airport data of airport Varna, which is airport number 215 out of 229
# Extracting the airport data of airport Vaxjo, which is airport number 216 out of 229
# Extracting the airport data of airport Venice (IT), which is airport number 217 out of 229
# Extracting the airport data of airport Verona, which is airport number 218 out of 229
# Extracting the airport data of airport Vienna, which is airport number 219 out of 229
# Extracting the airport data of airport Vigo, which is airport number 220 out of 229
# Extracting the airport data of airport Vilnius, which is airport number 221 out of 229
# Extracting the airport data of airport Visby, which is airport number 222 out of 229
# Extracting the airport data of airport Vitoria (ES), which is airport number 223 out of 229
# Extracting the airport data of airport Warsaw, which is airport number 224 out of 229
# Extracting the airport data of airport Wroclaw, which is airport number 225 out of 229
# Extracting the airport data of airport Zadar, which is airport number 226 out of 229
# Extracting the airport data of airport Zagreb, which is airport number 227 out of 229
# Extracting the airport data of airport Zakinthos Island, which is airport number 228 out of 229
# Extracting the airport data of airport Zaragoza, which is airport number 229 out of 229
